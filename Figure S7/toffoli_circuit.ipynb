# %% [markdown]
# # Figure S7: Fitness and Rounds-To-Success landscapes of all 16 Boolean functions

# %%
from matplotlib.colors import to_rgba
import matplotlib.pyplot as plt
import numpy as np

# %%
pauli_x_before = np.load('../Data/Figure S7/pauli_x_before.npy')
pauli_y_before = np.load('../Data/Figure S7/pauli_y_before.npy')
pauli_z_before = np.load('../Data/Figure S7/pauli_z_before.npy')

pauli_x_after = np.load('../Data/Figure S7/pauli_x_after.npy')
pauli_y_after = np.load('../Data/Figure S7/pauli_y_after.npy')
pauli_z_after = np.load('../Data/Figure S7/pauli_z_after.npy')

# %%
# Projection of Bloch vector onto the xoy
r_00_before = np.sqrt(pauli_y_before[0]**2+pauli_x_before[0]**2)
r_01_before = np.sqrt(pauli_y_before[1]**2+pauli_x_before[1]**2)
r_10_before = np.sqrt(pauli_y_before[2]**2+pauli_x_before[2]**2)
r_11_before = np.sqrt(pauli_y_before[3]**2+pauli_x_before[3]**2)
phi_00_before = np.mod(np.arctan2(pauli_y_before[0], pauli_x_before[0]), 2*np.pi)
phi_01_before = np.mod(np.arctan2(pauli_y_before[1], pauli_x_before[1]), 2*np.pi)
phi_10_before = np.mod(np.arctan2(pauli_y_before[2], pauli_x_before[2]), 2*np.pi)
phi_11_before = np.mod(np.arctan2(pauli_y_before[3], pauli_x_before[3]), 2*np.pi)

r_00_after = np.sqrt(pauli_y_after[0]**2+pauli_x_after[0]**2)
r_01_after = np.sqrt(pauli_y_after[1]**2+pauli_x_after[1]**2)
r_10_after = np.sqrt(pauli_y_after[2]**2+pauli_x_after[2]**2)
r_11_after = np.sqrt(pauli_y_after[3]**2+pauli_x_after[3]**2)
phi_00_after = np.mod(np.arctan2(pauli_y_after[0], pauli_x_after[0]), 2*np.pi)
phi_01_after = np.mod(np.arctan2(pauli_y_after[1], pauli_x_after[1]), 2*np.pi)
phi_10_after = np.mod(np.arctan2(pauli_y_after[2], pauli_x_after[2]), 2*np.pi)
phi_11_after = np.mod(np.arctan2(pauli_y_after[3], pauli_x_after[3]), 2*np.pi)

# Projection of Bloch vector onto the xoz
r_m_00_before = np.sqrt(pauli_z_before[0]**2+pauli_x_before[0]**2)
r_m_01_before = np.sqrt(pauli_z_before[1]**2+pauli_x_before[1]**2)
r_m_10_before = np.sqrt(pauli_z_before[2]**2+pauli_x_before[2]**2)
r_m_11_before = np.sqrt(pauli_z_before[3]**2+pauli_x_before[3]**2)
phi_m_00_before = np.mod(np.arctan2(pauli_z_before[0], pauli_x_before[0]), 2*np.pi)
phi_m_01_before = np.mod(np.arctan2(pauli_z_before[1], pauli_x_before[1]), 2*np.pi)
phi_m_10_before = np.mod(np.arctan2(pauli_z_before[2], pauli_x_before[2]), 2*np.pi)
phi_m_11_before = np.mod(np.arctan2(pauli_z_before[3], pauli_x_before[3]), 2*np.pi)

r_m_00_after = np.sqrt(pauli_z_after[0]**2+pauli_x_after[0]**2)
r_m_01_after = np.sqrt(pauli_z_after[1]**2+pauli_x_after[1]**2)
r_m_10_after = np.sqrt(pauli_z_after[2]**2+pauli_x_after[2]**2)
r_m_11_after = np.sqrt(pauli_z_after[3]**2+pauli_x_after[3]**2)
phi_m_00_after = np.mod(np.arctan2(pauli_z_after[0], pauli_x_after[0]), 2*np.pi)
phi_m_01_after = np.mod(np.arctan2(pauli_z_after[1], pauli_x_after[1]), 2*np.pi)
phi_m_10_after = np.mod(np.arctan2(pauli_z_after[2], pauli_x_after[2]), 2*np.pi)
phi_m_11_after = np.mod(np.arctan2(pauli_z_after[3], pauli_x_after[3]), 2*np.pi)

# Projection of Bloch vector onto the yoz
r_y_00_before = np.sqrt(pauli_z_before[0]**2+pauli_y_before[0]**2)
r_y_01_before = np.sqrt(pauli_z_before[1]**2+pauli_y_before[1]**2)
r_y_10_before = np.sqrt(pauli_z_before[2]**2+pauli_y_before[2]**2)
r_y_11_before = np.sqrt(pauli_z_before[3]**2+pauli_y_before[3]**2)
phi_y_00_before = np.mod(np.arctan2(pauli_z_before[0], pauli_y_before[0]), 2*np.pi)
phi_y_01_before = np.mod(np.arctan2(pauli_z_before[1], pauli_y_before[1]), 2*np.pi)
phi_y_10_before = np.mod(np.arctan2(pauli_z_before[2], pauli_y_before[2]), 2*np.pi)
phi_y_11_before = np.mod(np.arctan2(pauli_z_before[3], pauli_y_before[3]), 2*np.pi)
purity_00_before = 0.5*(1+np.sqrt(pauli_x_before[0]**2+pauli_y_before[0]**2+pauli_z_before[0]**2)**2)
purity_01_before = 0.5*(1+np.sqrt(pauli_x_before[1]**2+pauli_y_before[1]**2+pauli_z_before[1]**2)**2)
purity_10_before = 0.5*(1+np.sqrt(pauli_x_before[2]**2+pauli_y_before[2]**2+pauli_z_before[2]**2)**2)
purity_11_before = 0.5*(1+np.sqrt(pauli_x_before[3]**2+pauli_y_before[3]**2+pauli_z_before[3]**2)**2)

r_y_00_after = np.sqrt(pauli_z_after[0]**2+pauli_y_after[0]**2)
r_y_01_after = np.sqrt(pauli_z_after[1]**2+pauli_y_after[1]**2)
r_y_10_after = np.sqrt(pauli_z_after[2]**2+pauli_y_after[2]**2)
r_y_11_after = np.sqrt(pauli_z_after[3]**2+pauli_y_after[3]**2)
phi_y_00_after = np.mod(np.arctan2(pauli_z_after[0], pauli_y_after[0]), 2*np.pi)
phi_y_01_after = np.mod(np.arctan2(pauli_z_after[1], pauli_y_after[1]), 2*np.pi)
phi_y_10_after = np.mod(np.arctan2(pauli_z_after[2], pauli_y_after[2]), 2*np.pi)
phi_y_11_after = np.mod(np.arctan2(pauli_z_after[3], pauli_y_after[3]), 2*np.pi)
purity_00_after = 0.5*(1+np.sqrt(pauli_x_after[0]**2+pauli_y_after[0]**2+pauli_z_after[0]**2)**2)
purity_01_after = 0.5*(1+np.sqrt(pauli_x_after[1]**2+pauli_y_after[1]**2+pauli_z_after[1]**2)**2)
purity_10_after = 0.5*(1+np.sqrt(pauli_x_after[2]**2+pauli_y_after[2]**2+pauli_z_after[2]**2)**2)
purity_11_after = 0.5*(1+np.sqrt(pauli_x_after[3]**2+pauli_y_after[3]**2+pauli_z_after[3]**2)**2)

# %%
FONT_SIZE = 14
color = 'tab:red'
fig = plt.figure(figsize=(20,8), dpi=600)
plt.rcParams.update({'font.size': 10})
plt.subplots_adjust(wspace=0.2, hspace=0.3)
axs = [fig.add_subplot(441), fig.add_subplot(445), fig.add_subplot(449), fig.add_subplot(4,4,13),  
       fig.add_subplot(443), fig.add_subplot(447), fig.add_subplot(4,4,11), fig.add_subplot(4,4,15),
       fig.add_subplot(342, projection='polar'), fig.add_subplot(346, projection='polar'), fig.add_subplot(3,4,10, projection='polar'),
       fig.add_subplot(344, projection='polar'), fig.add_subplot(348, projection='polar'), fig.add_subplot(3,4,12, projection='polar')]

# Tomograph plot before 
axs[0].bar([2], [1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[0].bar([0,1,2], [pauli_x_before[0], pauli_y_before[0], pauli_z_before[0]], fc=to_rgba(color, alpha=1))
axs[0].set_ylim(-1.1, 1.1)
axs[0].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[0].set_xlim(-.5, 2.5)
axs[0].set_xticks([0,1,2])
axs[0].set_xticklabels(['','', ''])
axs[0].text(-.4, .65, r'Control $|0_\mathrm{I1}0_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[0].text(-.4, .3, f'Purity: {purity_00_before:.2f}', fontsize=FONT_SIZE)
axs[0].set_title('(a)', x = -0.1 , y = 1.03, fontsize=16)

axs[1].bar([2], [1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[1].bar([0,1,2], [pauli_x_before[1], pauli_y_before[1], pauli_z_before[1]], fc=to_rgba(color, alpha=1))
axs[1].set_ylim(-1.1, 1.1)
axs[1].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[1].set_xlim(-.5, 2.5)
axs[1].set_xticks([0,1,2])
axs[1].set_xticklabels(['','', ''])
axs[1].text(-.4, .65, r'Control $|0_\mathrm{I1}1_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[1].text(-.4, .3, f'Purity: {purity_01_before:.2f}', fontsize=FONT_SIZE)
axs[1].set_title('(b)', x = -0.1 , y = 1.03, fontsize=16)

axs[2].bar([2], [1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[2].bar([0,1,2], [pauli_x_before[2], pauli_y_before[2], pauli_z_before[2]], fc=to_rgba(color, alpha=1))
axs[2].set_ylim(-1.1, 1.1)
axs[2].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[2].set_xlim(-.5, 2.5)
axs[2].set_xticks([0,1,2])
axs[2].set_xticklabels(['','', ''])
axs[2].text(-.4, .65, r'Control $|1_\mathrm{I1}0_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[2].text(-.4, .3, f'Purity: {purity_10_before:.2f}', fontsize=FONT_SIZE)
axs[2].set_title('(c)', x = -0.1 , y = 1.03, fontsize=16)

axs[3].bar([2], [-1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[3].bar([0,1,2], [pauli_x_before[3], pauli_y_before[3], pauli_z_before[3]], fc=to_rgba(color, alpha=1))
axs[3].set_ylim(-1.1, 1.1)
axs[3].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[3].set_xlim(-.5, 2.5)
axs[3].set_xticks([0,1,2])
axs[3].set_xticklabels([r'$X_\mathrm{A}$', r'$Y_\mathrm{A}$', r'$Z_\mathrm{A}$'], fontsize=16)
axs[3].text(-.4, .65, r'Control $|1_\mathrm{I1}1_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[3].text(-.4, .3, f'Purity: {purity_11_before:.2f}', fontsize=FONT_SIZE)
axs[3].set_title('(d)', x = -0.1 , y = 1.03, fontsize=16)

# Tomograph plot after
axs[4].bar([2], [1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[4].bar([0,1,2], [pauli_x_after[0], pauli_y_after[0], pauli_z_after[0]], fc=to_rgba(color, alpha=1))
axs[4].set_ylim(-1.1, 1.1)
axs[4].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[4].set_xlim(-.5, 2.5)
axs[4].set_xticks([0,1,2])
axs[4].set_xticklabels(['','', ''])
axs[4].text(-.4, .65, r'Control $|0_\mathrm{I1}0_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[4].text(-.4, .3, f'Purity: {purity_00_after:.2f}', fontsize=FONT_SIZE)
axs[4].set_title('(h)', x = -0.1 , y = 1.03, fontsize=16)

axs[5].bar([2], [1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[5].bar([0,1,2], [pauli_x_after[1], pauli_y_after[1], pauli_z_after[1]], fc=to_rgba(color, alpha=1))
axs[5].set_ylim(-1.1, 1.1)
axs[5].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[5].set_xlim(-.5, 2.5)
axs[5].set_xticks([0,1,2])
axs[5].set_xticklabels(['','', ''])
axs[5].text(-.4, .65, r'Control $|0_\mathrm{I1}1_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[5].text(-.4, .3, f'Purity: {purity_01_after:.2f}', fontsize=FONT_SIZE)
axs[5].set_title('(i)', x = -0.1 , y = 1.03, fontsize=16)

axs[6].bar([2], [1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[6].bar([0,1,2], [pauli_x_after[2], pauli_y_after[2], pauli_z_after[2]], fc=to_rgba(color, alpha=1))
axs[6].set_ylim(-1.1, 1.1)
axs[6].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[6].set_xlim(-.5, 2.5)
axs[6].set_xticks([0,1,2])
axs[6].set_xticklabels(['','', ''])
axs[6].text(-.4, .65, r'Control $|1_\mathrm{I1}0_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[6].text(-.4, .3, f'Purity: {purity_10_after:.2f}', fontsize=FONT_SIZE)
axs[6].set_title('(j)', x = -0.1 , y = 1.03, fontsize=16)

axs[7].bar([2], [-1], ls='--', ec='k', fc=to_rgba(color, alpha=.1))
axs[7].bar([0,1,2], [pauli_x_after[3], pauli_y_after[3], pauli_z_after[3]], fc=to_rgba(color, alpha=1))
axs[7].set_ylim(-1.1, 1.1)
axs[7].set_ylabel(r'$\langle P\rangle$', labelpad=-5, fontsize=16)
axs[7].set_xlim(-.5, 2.5)
axs[7].set_xticks([0,1,2])
axs[7].set_xticklabels([r'$X_\mathrm{A}$', r'$Y_\mathrm{A}$', r'$Z_\mathrm{A}$'], fontsize=16)
axs[7].text(-.4, .65, r'Control $|1_\mathrm{I1}1_\mathrm{I2}\rangle$', fontsize=FONT_SIZE)
axs[7].text(-.4, .3, f'Purity: {purity_11_after:.2f}', fontsize=FONT_SIZE)
axs[7].set_title('(k)', x = -0.1 , y = 1.03, fontsize=16)

# Polar plot before
axs[8].set_rlim(0, 1)
axs[8].set_rticks(np.linspace(0,1,3))
axs[8].plot([0, phi_00_before], [0, r_00_before], 'C0--', alpha=.5, lw=1)
axs[8].plot([0, phi_01_before], [0, r_01_before], 'C1--', alpha=.5, lw=1)
axs[8].plot([0, phi_10_before], [0, r_10_before], 'C2--', alpha=.5, lw=1)
axs[8].plot([0, phi_11_before], [0, r_11_before], 'C3--', alpha=.5, lw=1)
axs[8].plot([phi_00_before], [r_00_before], 'C0o', label=r'Control $|00\rangle$')
axs[8].plot([phi_01_before], [r_01_before], 'C1o', label=r'Control $|01\rangle$')
axs[8].plot([phi_10_before], [r_10_before], 'C2o', label=r'Control $|10\rangle$')
axs[8].plot([phi_11_before], [r_11_before], 'C3o', label=r'Control $|11\rangle$')
axs[8].set_title('XoY plane', rotation=90, x = -0.4, y = 0.45, horizontalalignment='center', verticalalignment='center', fontsize=16)
axs[8].text(s = '(e)', x = -0.2 , y = 1.05, fontsize=16, rotation=0, transform = axs[8].transAxes)

axs[9].set_rlim(0, 1)
axs[9].set_rticks(np.linspace(0,1,3))
axs[9].plot([0, phi_m_00_before], [0, r_m_00_before], 'C0--', alpha=.5, lw=1)
axs[9].plot([0, phi_m_01_before], [0, r_m_01_before], 'C1--', alpha=.5, lw=1)
axs[9].plot([0, phi_m_10_before], [0, r_m_10_before], 'C2--', alpha=.5, lw=1)
axs[9].plot([0, phi_m_11_before], [0, r_m_11_before], 'C3--', alpha=.5, lw=1)
axs[9].plot([phi_m_00_before], [r_m_00_before], 'C0o', label=r'Control $|00\rangle$')
axs[9].plot([phi_m_01_before], [r_m_01_before], 'C1o', label=r'Control $|01\rangle$')
axs[9].plot([phi_m_10_before], [r_m_10_before], 'C2o', label=r'Control $|10\rangle$')
axs[9].plot([phi_m_11_before], [r_m_11_before], 'C3o', label=r'Control $|11\rangle$')
axs[9].set_title('XoZ plane', rotation=90, x = -0.4, y = 0.45, horizontalalignment='center', verticalalignment='center', fontsize=16)
axs[9].text(s = '(f)', x = -0.2 , y = 1.05, fontsize=16, rotation=0, transform = axs[9].transAxes)

axs[10].set_rlim(0, 1)
axs[10].set_rticks(np.linspace(0,1,3))
axs[10].plot([0, phi_y_00_before], [0, r_y_00_before], 'C0--', alpha=.5, lw=1)
axs[10].plot([0, phi_y_01_before], [0, r_y_01_before], 'C1--', alpha=.5, lw=1)
axs[10].plot([0, phi_y_10_before], [0, r_y_10_before], 'C2--', alpha=.5, lw=1)
axs[10].plot([0, phi_y_11_before], [0, r_y_11_before], 'C3--', alpha=.5, lw=1)
axs[10].plot([phi_y_00_before], [r_y_00_before], 'C0o', label=r'Control $|00\rangle$')
axs[10].plot([phi_y_01_before], [r_y_01_before], 'C1o', label=r'Control $|01\rangle$')
axs[10].plot([phi_y_10_before], [r_y_10_before], 'C2o', label=r'Control $|10\rangle$')
axs[10].plot([phi_y_11_before], [r_y_11_before], 'C3o', label=r'Control $|11\rangle$')
axs[10].set_title('YoZ plane', rotation=90, x = -0.4, y = 0.45, horizontalalignment='center', verticalalignment='center', fontsize=16)
axs[10].text(s = '(g)', x = -0.2 , y = 1.05, fontsize=16, rotation=0, transform = axs[10].transAxes)

# Polar plot after
axs[11].set_rlim(0, 1)
axs[11].set_rticks(np.linspace(0,1,3))
axs[11].plot([0, phi_00_after], [0, r_00_after], 'C0--', alpha=.5, lw=1)
axs[11].plot([0, phi_01_after], [0, r_01_after], 'C1--', alpha=.5, lw=1)
axs[11].plot([0, phi_10_after], [0, r_10_after], 'C2--', alpha=.5, lw=1)
axs[11].plot([0, phi_11_after], [0, r_11_after], 'C3--', alpha=.5, lw=1)
axs[11].plot([phi_00_after], [r_00_after], 'C0o', label=r'Control $|00\rangle$')
axs[11].plot([phi_01_after], [r_01_after], 'C1o', label=r'Control $|01\rangle$')
axs[11].plot([phi_10_after], [r_10_after], 'C2o', label=r'Control $|10\rangle$')
axs[11].plot([phi_11_after], [r_11_after], 'C3o', label=r'Control $|11\rangle$')
axs[11].set_title('XoY plane', rotation=90, x = -0.4, y = 0.45, horizontalalignment='center', verticalalignment='center', fontsize=16)
axs[11].text(s = '(l)', x = -0.2 , y = 1.05, fontsize=16, rotation=0, transform = axs[11].transAxes)

axs[12].set_rlim(0, 1)
axs[12].set_rticks(np.linspace(0,1,3))
axs[12].plot([0, phi_m_00_after], [0, r_m_00_after], 'C0--', alpha=.5, lw=1)
axs[12].plot([0, phi_m_01_after], [0, r_m_01_after], 'C1--', alpha=.5, lw=1)
axs[12].plot([0, phi_m_10_after], [0, r_m_10_after], 'C2--', alpha=.5, lw=1)
axs[12].plot([0, phi_m_11_after], [0, r_m_11_after], 'C3--', alpha=.5, lw=1)
axs[12].plot([phi_m_00_after], [r_m_00_after], 'C0o', label=r'Control $|00\rangle$')
axs[12].plot([phi_m_01_after], [r_m_01_after], 'C1o', label=r'Control $|01\rangle$')
axs[12].plot([phi_m_10_after], [r_m_10_after], 'C2o', label=r'Control $|10\rangle$')
axs[12].plot([phi_m_11_after], [r_m_11_after], 'C3o', label=r'Control $|11\rangle$')
axs[12].set_title('XoZ plane)', rotation=90, x = -0.4, y = 0.45, horizontalalignment='center', verticalalignment='center', fontsize=16)
axs[12].text(s = '(m)', x = -0.2 , y = 1.05, fontsize=16, rotation=0, transform = axs[12].transAxes)

axs[13].set_rlim(0, 1)
axs[13].set_rticks(np.linspace(0,1,3))
axs[13].plot([0, phi_y_00_after], [0, r_y_00_after], 'C0--', alpha=.5, lw=1)
axs[13].plot([0, phi_y_01_after], [0, r_y_01_after], 'C1--', alpha=.5, lw=1)
axs[13].plot([0, phi_y_10_after], [0, r_y_10_after], 'C2--', alpha=.5, lw=1)
axs[13].plot([0, phi_y_11_after], [0, r_y_11_after], 'C3--', alpha=.5, lw=1)
axs[13].plot([phi_y_00_after], [r_y_00_after], 'C0o', label=r'Control $|0_\mathrm{I1}0_\mathrm{I2}\rangle$')
axs[13].plot([phi_y_01_after], [r_y_01_after], 'C1o', label=r'Control $|0_\mathrm{I1}1_\mathrm{I2}\rangle$')
axs[13].plot([phi_y_10_after], [r_y_10_after], 'C2o', label=r'Control $|1_\mathrm{I1}0_\mathrm{I2}\rangle$')
axs[13].plot([phi_y_11_after], [r_y_11_after], 'C3o', label=r'Control $|1_\mathrm{I1}1_\mathrm{I2}\rangle$')
axs[13].set_title('YoZ plane)', rotation=90, x = -0.4, y = 0.45, horizontalalignment='center', verticalalignment='center', fontsize=16)
axs[13].text(s = '(n)', x = -0.2 , y = 1.05, fontsize=16, rotation=0, transform = axs[13].transAxes)
axs[13].legend(frameon=False, bbox_to_anchor=(-1, -0.35), fontsize=FONT_SIZE, ncol=4)

axs[3].text(s='Pauli operator P', x=0.5 , y=-0.35, fontsize=FONT_SIZE, horizontalalignment='center', verticalalignment='center', transform = axs[3].transAxes)
axs[7].text(s='Pauli operator P', x=0.5 , y=-0.35, fontsize=FONT_SIZE, horizontalalignment='center', verticalalignment='center', transform = axs[7].transAxes)

plt.savefig(fname=f'Figure_S7.pdf', bbox_inches = 'tight')
